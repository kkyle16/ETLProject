# %%
import json

# %%
file=open('pokemon_first.json')

# %%
data = json.load(file)

# %%
import pprint as pprint

# %%
print(data[3])
# Out:
# {'Id': '004', 'Name': 'Charmander', 'Type 1': 'Fire', 'Type 2': 'None', 'Abilities': ['Blaze', 'Solar Power'], 'Category': 'Lizard Pokémon', 'Height (ft)': '2\'00"', 'Height (m)': '0.6', 'Weight (lbs)': '18.7', 'Weight (kg)': '8.5', 'Capture Rate': '45', 'Egg Steps': '5120', 'Exp Group': 'Medium Slow', 'Total': '309', 'HP': '39', 'Attack': '52', 'Defense': '43', 'Sp. Attack': '60', 'Sp. Defense': '50', 'Speed': '65', 'Moves': {'Scratch': {'Type': 'Normal', 'Level': '—', 'Power': '40', 'Accuracy': '100', 'PP': '35', 'Effect %': '--', 'Description': 'Hard, pointed, sharp claws rake the target to inflict damage.'}, 'Growl': {'Type': 'Normal', 'Level': '—', 'Power': '--', 'Accuracy': '100', 'PP': '40', 'Effect %': '--', 'Description': 'The user growls in an endearing way, making opposing Pokémon less wary. This lowers their Attack stat.'}, 'Ember': {'Type': 'Fire', 'Level': '7', 'Power': '40', 'Accuracy': '100', 'PP': '25', 'Effect %': '10', 'Description': 'The target is attacked with sm
# ...

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(data[1])
# Out:
# {   'Abilities': ['Overgrow', 'Chlorophyll'],
#     'Attack': '62',
#     'Capture Rate': '45',
#     'Category': 'Seed Pokémon',
#     'Defense': '63',
#     'Egg Steps': '5120',
#     'Exp Group': 'Medium Slow',
#     'HP': '60',
#     'Height (ft)': '3\'03"',
#     'Height (m)': '1',
#     'Id': '002',
#     'Moves': {   'Double-Edge': {   'Accuracy': '100',
#                                     'Description': 'A reckless, life-risking '
#                                                    'tackle. This also damages '
#                                                    'the user quite a lot.',
#                                     'Effect %': '--',
#                                     'Level': '31',
#                                     'PP': '15',
#                                     'Power': '120',
#                                     'Type': 'Normal'},
#                  'Growl': {   'Accuracy': '100',
# ...

# %%
# Closing file 
file.close()

# %%
import pandas as pd
jsondata=pd.read_json ('pokemon_first.json')

# %%
print(jsondata)
# Out:
#       Id         Name    Type 1  Type 2                Abilities  \
# 0      1    Bulbasaur     Grass  Poison  [Overgrow, Chlorophyll]
# 1      2      Ivysaur     Grass  Poison  [Overgrow, Chlorophyll]
# 2      3     Venusaur     Grass  Poison  [Overgrow, Chlorophyll]
# 3      4   Charmander      Fire    None     [Blaze, Solar Power]
# 4      5   Charmeleon      Fire    None     [Blaze, Solar Power]
# ..   ...          ...       ...     ...                      ...
# 804  805    Stakataka      Rock   Steel            [Beast Boost]
# 805  806  Blacephalon      Fire   Ghost            [Beast Boost]
# 806  807      Zeraora  Electric    None            [Volt Absorb]
# 807  808       Meltan     Steel    None            [Magnet Pull]
# 808  809     Melmetal     Steel    None              [Iron Fist]
#
#                 Category Height (ft)  Height (m)  Weight (lbs)  Weight (kg)  \
# 0           Seed Pokémon       2'04"         0.7          15.2          6.9
# ...

# %%
df=pd.DataFrame(jsondata)

# %%
df
# Out:
#       Id         Name    Type 1  Type 2                Abilities  \
# 0      1    Bulbasaur     Grass  Poison  [Overgrow, Chlorophyll]
# 1      2      Ivysaur     Grass  Poison  [Overgrow, Chlorophyll]
# 2      3     Venusaur     Grass  Poison  [Overgrow, Chlorophyll]
# 3      4   Charmander      Fire    None     [Blaze, Solar Power]
# 4      5   Charmeleon      Fire    None     [Blaze, Solar Power]
# ..   ...          ...       ...     ...                      ...
# 804  805    Stakataka      Rock   Steel            [Beast Boost]
# 805  806  Blacephalon      Fire   Ghost            [Beast Boost]
# 806  807      Zeraora  Electric    None            [Volt Absorb]
# 807  808       Meltan     Steel    None            [Magnet Pull]
# 808  809     Melmetal     Steel    None              [Iron Fist]
#
#                 Category Height (ft)  Height (m)  Weight (lbs)  Weight (kg)  \
# 0           Seed Pokémon       2'04"         0.7          15.2          6.9
# ...
